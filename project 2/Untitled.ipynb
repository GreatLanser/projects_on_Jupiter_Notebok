# %%
import pandas as pd

# %%
df = pd.read_csv('wheat_usa_1909-2020.csv')

# %%
df.head(10)
# Out:
#   Program  Year Period  Week Ending Geo Level       State  State ANSI  \
# 0  SURVEY  2020   YEAR          NaN     STATE     ALABAMA           1
# 1  SURVEY  2020   YEAR          NaN     STATE     ARIZONA           4
# 2  SURVEY  2020   YEAR          NaN     STATE    ARKANSAS           5
# 3  SURVEY  2020   YEAR          NaN     STATE  CALIFORNIA           6
# 4  SURVEY  2020   YEAR          NaN     STATE    COLORADO           8
# 5  SURVEY  2020   YEAR          NaN     STATE    DELAWARE          10
# 6  SURVEY  2020   YEAR          NaN     STATE     GEORGIA          13
# 7  SURVEY  2020   YEAR          NaN     STATE       IDAHO          16
# 8  SURVEY  2020   YEAR          NaN     STATE    ILLINOIS          17
# 9  SURVEY  2020   YEAR          NaN     STATE     INDIANA          18
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# ...

# %%
df.drop(['Program', 'Period', 'Week Ending', 'Geo Level', 'Ag District', 'Ag District Code', 'County'], axis=1)
# Out:
#       Year Period  Week Ending Geo Level         State  State ANSI  \
# 0     2020   YEAR          NaN     STATE       ALABAMA           1
# 1     2020   YEAR          NaN     STATE       ARIZONA           4
# 2     2020   YEAR          NaN     STATE      ARKANSAS           5
# 3     2020   YEAR          NaN     STATE    CALIFORNIA           6
# 4     2020   YEAR          NaN     STATE      COLORADO           8
# ...    ...    ...          ...       ...           ...         ...
# 3071  1911   YEAR          NaN     STATE  NORTH DAKOTA          38
# 3072  1910   YEAR          NaN     STATE       ARIZONA           4
# 3073  1910   YEAR          NaN     STATE  NORTH DAKOTA          38
# 3074  1909   YEAR          NaN     STATE       ARIZONA           4
# 3075  1909   YEAR          NaN     STATE  NORTH DAKOTA          38
#
#       Ag District  Ag District Code  County  County ANSI  Zip Code  Region  \
# 0             NaN               NaN     NaN          NaN       NaN     NaN
# ...
